# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
from fig6code import *

# %%
file = 'data/lake_bathymetry_check.h5'
imagery_filename = 'data/S2A_MSIL2A_20190716T151911_N0213_R068_T22WEB_20190716T175434.tif'

plotname = '../figures/fig06-bathymetry_check.jpg'

# some figure settings 
major_frames = [5, 12] # the indices of the major frames to be plotted in detail
yl1 = (1170, 1225)
yl2 = [1185,1204]
yl3 = [1185,1204]
dot_size = 20

fig = make_plot(file, major_frames, yl1, yl2, yl3, dot_size=dot_size, imagery_filename=imagery_filename, re_download_imagery=False)
fig.savefig(plotname , dpi=600)
plt.close(fig)

# show plot and print info
display(Image(plotname))
print_lake_info(file)
major_frame_info_bathymetry_check = get_major_frame_level_info(dictobj(read_melt_lake_h5(file)).mframe_data)
# Out:
# LAKE INFO:
#   granule_id:            ATL03_20190716051841_02770403_006_02.h5
#   RGT:                   277
#   GTX:                   GT3R
#   beam:                  6 (weak)
#   acquisition time:      2019-07-16T05:21:08Z
#   center location:       (48.56887W, 68.90620N)
#   ice sheet:             GrIS
#   melt season:           2019
#   IMAGERY INFO:
#     product ID:                     S2A_MSIL2A_20190716T151911_N0213_R068_T22WEB_20190716T175434
#     acquisition time imagery:       2019-07-16T08:23:33Z
#     acquisition time ICESat-2:      2019-07-16T05:21:08Z
#     time difference from ICESat-2:  3:02:25.924000 (Same day as ICESat-2)
#     mean cloud probability:         8.5 %

# %% [markdown]
# ## bathymetry check results for all major frames

# %%
major_frame_info_bathymetry_check
# Out:
#           idx  passes_bathymetry_check    peak    xatc    q_1    q_2    q_3  \
# mframe
# 57689846    0                    False  1209.7    70.5  0.000  0.000  0.000
# 57689847    1                    False  1204.8   213.2  0.000  0.000  0.000
# 57689848    2                    False  1200.6   355.5  0.000  0.000  0.000
# 57689849    3                     True  1200.6   495.8  1.000  1.000  1.000
# 57689850    4                     True  1200.6   639.0  1.000  1.000  1.000
# 57689851    5                     True  1200.5   782.0  0.854  1.000  1.000
# 57689852    6                     True  1200.5   923.7  0.854  0.806  1.000
# 57689853    7                     True  1200.5  1065.8  0.586  0.527  1.000
# 57689854    8                     True  1200.5  1208.1  0.465  0.543  1.000
# 57689855    9                     True  1200.6  1349.5  0.854  0.737  1.000
# 57689856   10                     True  1200.6  1491.0  0.586  0.546  1.000
# 57689857   11                    False  1200.6  1633.6  0.164  0.246  1.000
# 57689858   12                    False  1200.5  1775.5  0.164  0.157  0.945
# 57689859   13                     True  1200.6  1918.1  0.354  0.296  1.000
# 57689860   14                    False  1202.2  2059.4  0.000  0.000  0.000
# 57689861   15                    False  1205.0  2201.1  0.000  0.000  0.000
#
#             q_4    q_s
# mframe
# 57689846  0.000  0.000
# 57689847  0.000  0.000
# 57689848  0.000  0.000
# 57689849  0.956  0.956
# 57689850  0.944  0.944
# 57689851  0.954  0.815
# 57689852  0.827  0.569
# 57689853  0.816  0.252
# 57689854  0.987  0.249
# 57689855  0.842  0.529
# 57689856  0.865  0.277
# 57689857  0.883  0.036
# 57689858  1.000  0.024
# 57689859  0.965  0.101
# 57689860  0.000  0.000
# 57689861  0.000  0.000
